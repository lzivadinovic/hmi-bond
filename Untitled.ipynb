# %%
from enhance import enhance
import sunpy.map
# Load noaa2harp module
from noaa2harp import noaa2harp
import requests
import glob
import os
# Process needs more testing
from process import process_continuum

# %%
#just test enhance
mapa = sunpy.map.Map('hmi.sharp_cea_720s.3604.20140108_031200_TAI.continuum.fits')
o = enhance.enhance(inputFile=mapa, depth=5, model='keepsize', activation='relu', ntype='intensity', output='1.fits', rtype='spmap')
o.define_network()
mapa2 = o.predict()
mapa.peek()
mapa2.peek()
# ctype1, ctype2, 
#mapa.meta
# Out:
# Setting up network...
# Loading weights...
# Predicting data...
# (1, 800, 1524, 1)
# Prediction took 3.6 seconds...
# Updating header ...

# %%
# initialize object and get harpnum
a = noaa2harp()
a.update_dataset()
HARPNUM = a.noaa2harp("11950")
print(HARPNUM)
# Out:
# Default HARP_TO_NOAA exists
# Loading file
# Content fetched, saving...
# File saved to ./HARP_TO_NOAA.txt
# Loading new dataset
# 3604

# %%
# create query and fetch data
MY_MAIL='lazar.zivadinovic.994@gmail.com'
import os
# Lets make jsoc query 
from sunpy.net import jsoc
from sunpy.net import attrs as a
from sunpy.time import parse_time
#initialize client
client = jsoc.JSOCClient()

data_root='./data'
#DOWNLOAD_PATH_FOR_RAW_DATA
download_path=os.path.join(data_root,str(HARPNUM),'raw')

###### THIS IS THE REAL QUERY, LETS MAKE SOMETHING SMALLER FOR TESTING ########
# Create query
resjsoc = client.search(a.jsoc.PrimeKey('HARPNUM', HARPNUM),
                        a.jsoc.Series('hmi.sharp_cea_720s'),
                        a.jsoc.Segment('Bp') & a.jsoc.Segment('Bt') & 
                        a.jsoc.Segment('Br') & a.jsoc.Segment('continuum'))#,
                        #a.jsoc.Notify(MY_MAIL))

#Lets fetch few images for testing
#Note that client.jsoc does not support slice, so we need new query
#This is a way around it
# Small samplesize lets test on 4 imgs
T1 = resjsoc.table['T_REC'][0]
T2 = resjsoc.table['T_REC'][3]
resjsoc = client.search(a.jsoc.PrimeKey('HARPNUM', HARPNUM),
                        a.Time(T1,T2),
                        a.jsoc.Series('hmi.sharp_cea_720s'),
                        a.jsoc.Segment('Bp') & a.jsoc.Segment('Bt') & 
                        a.jsoc.Segment('Br') & a.jsoc.Segment('continuum'),
                        a.jsoc.Notify(MY_MAIL))

result = client.fetch(resjsoc, path=download_path, progress=True, wait=True)

if result.errors:
    print("We had some errors, here is log")
    print(result.errors)
    print("Lets fetch them via requests library")
    for reserr in result.errors:
        r = requests.get(reserr.url)
        if r.ok:
            print("Content fetched, saving...")
        path_for_new_img = os.path.join(download_path,reserr.url.split('/')[-1])
        with open(path_for_new_img, 'wb') as f:
            f.write(r.content)
            print("File saved to {}".format(path_for_new_img))
    #we should have all results now, lets update results list
    result = glob.glob(os.path.join(download_path,'*'))
# Out:
# Export request pending. [id="JSOC_20200601_2409", status=2]
# Waiting for 0 seconds...
# Files Downloaded:   0%|          | 0/16 [00:00<?, ?file/s]
# 16 URLs found for download. Full request totalling 7MB
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Bt.fits:   0%|          | 0.00/573k [00:00<?, ?B/s]
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Bp.fits:   0%|          | 0.00/510k [00:00<?, ?B/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Br.fits:   0%|          | 0.00/559k [00:00<?, ?B/s]
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.continuum.fits:   0%|          | 0.00/323k [00:00<?, ?B/s]
#
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Bt.fits:   0%|          | 100/573k [00:00<34:01, 281B/s]
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.continuum.fits:   0%|          | 100/323k [00:00<18:57, 284B/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Br.fits:   0%|          | 100/559k [00:00<33:49, 275B/s]
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Bp.fits:   0%|          | 100/510k [00:00<31:17, 271B/s]
#
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Bt.fits:   1%|▏         | 8.02k/573k [00:00<23:32, 400B/s]
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.continuum.fits:   2%|▏         | 8.02k/323k [00:00<12:58, 404B/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Br.fits:   1%|          | 4.06k/559k [00:00<23:37, 391B/s]
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Bp.fits:   1%|          | 4.06k/510k [00:00<21:51, 386B/s]
#
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Bt.fits:   4%|▍         | 22.3k/573k [00:00<16:05, 570B/s]
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.continuum.fits:   7%|▋         | 23.7k/323k [00:00<08:38, 576B/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Br.fits:   2%|▏         | 11.2k/559k [00:00<16:23, 557B/s]
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Bp.fits:   2%|▏         | 12.6k/510k [00:00<15:05, 549B/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_032400_TAI.Br.fits:   0%|          | 0.00/559k [00:00<?, ?B/s]
#
# hmi.sharp_cea_720s.3604.20140108_032400_TAI.Bt.fits:   0%|          | 0.00/573k [00:00<?, ?B/s]
#
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Bt.fits:   8%|▊         | 43.7k/573k [00:00<10:51, 813B/s]
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.continuum.fits:  15%|█▍        | 48.0k/323k [00:00<05:34, 822B/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Br.fits:   4%|▍         | 22.6k/559k [00:00<11:16, 792B/s]
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Bp.fits:   5%|▌         | 26.9k/510k [00:00<10:17, 782B/s]
#
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Bt.fits:  14%|█▍        | 79.4k/573k [00:01<07:05, 1.16kB/s]
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.continuum.fits:  26%|██▋       | 85.1k/323k [00:01<03:22, 1.17kB/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Br.fits:   7%|▋         | 39.8k/559k [00:01<07:40, 1.13kB/s]
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Bp.fits:   9%|▉         | 46.9k/510k [00:01<06:55, 1.11kB/s]
#
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Bt.fits:  23%|██▎       | 129k/573k [00:01<04:28, 1.65kB/s]
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.continuum.fits:  41%|████      | 132k/323k [00:01<01:53, 1.67kB/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Br.fits:  12%|█▏        | 65.5k/559k [00:01<05:07, 1.61kB/s]
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Bp.fits:  15%|█▍        | 75.5k/510k [00:01<04:33, 1.59kB/s]
#
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Bt.fits:  34%|███▎      | 192k/573k [00:01<02:41, 2.36kB/s]
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.continuum.fits:  61%|██████    | 197k/323k [00:01<00:52, 2.38kB/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Br.fits:  17%|█▋        | 95.5k/559k [00:01<03:22, 2.28kB/s]
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Bp.fits:  21%|██        | 108k/510k [00:01<02:57, 2.26kB/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_033600_TAI.Bt.fits:   0%|          | 0.00/573k [00:00<?, ?B/s]
#
# hmi.sharp_cea_720s.3604.20140108_033600_TAI.Br.fits:   0%|          | 0.00/559k [00:00<?, ?B/s]
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.continuum.fits:  91%|█████████ | 292k/323k [00:01<00:08, 3.40kB/s]
#
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Bt.fits:  48%|████▊     | 278k/573k [00:01<01:27, 3.36kB/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Br.fits:  24%|██▎       | 133k/559k [00:01<02:11, 3.25kB/s]
# Files Downloaded:   6%|▋         | 1/16 [00:01<00:29,  1.96s/file]
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Bp.fits:  28%|██▊       | 144k/510k [00:01<01:53, 3.21kB/s]
#
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Bt.fits:  66%|██████▌   | 376k/573k [00:01<00:41, 4.79kB/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Br.fits:  32%|███▏      | 177k/559k [00:01<01:22, 4.62kB/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_033600_TAI.Bt.fits:   0%|          | 100/573k [00:00<34:28, 277B/s]
#
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Bt.fits:  89%|████████▉ | 511k/573k [00:01<00:09, 6.82kB/s]
#
#
# Files Downloaded:  12%|█▎        | 2/16 [00:02<00:20,  1.47s/file]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_033600_TAI.Bt.fits:   1%|          | 4.06k/573k [00:00<24:05, 394B/s]
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.continuum.fits:   0%|          | 0.00/323k [00:00<?, ?B/s]
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bt.fits:   0%|          | 0.00/573k [00:00<?, ?B/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bp.fits:   0%|          | 0.00/510k [00:00<?, ?B/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_033600_TAI.Bt.fits:   2%|▏         | 11.2k/573k [00:00<16:43, 560B/s]
#
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Br.fits:   0%|          | 0.00/559k [00:00<?, ?B/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_033600_TAI.Bt.fits:   4%|▍         | 24.1k/573k [00:00<11:28, 798B/s]
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.continuum.fits:   0%|          | 100/323k [00:00<18:38, 288B/s]
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bt.fits:   0%|          | 100/573k [00:00<33:13, 287B/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bp.fits:   0%|          | 100/510k [00:00<29:57, 284B/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_033600_TAI.Bt.fits:   8%|▊         | 45.5k/573k [00:01<07:44, 1.14kB/s]
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.continuum.fits:   2%|▏         | 8.02k/323k [00:00<12:45, 411B/s]
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bt.fits:   1%|▏         | 8.02k/573k [00:00<22:59, 410B/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bp.fits:   1%|          | 4.06k/510k [00:00<20:55, 403B/s]
#
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Br.fits:   0%|          | 100/559k [00:00<31:50, 292B/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_033600_TAI.Bt.fits:  13%|█▎        | 76.9k/573k [00:01<05:06, 1.62kB/s]
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.continuum.fits:   7%|▋         | 23.7k/323k [00:00<08:30, 586B/s]
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bt.fits:   4%|▍         | 22.3k/573k [00:00<15:43, 584B/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bp.fits:   2%|▏         | 11.2k/510k [00:00<14:30, 573B/s]
#
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Br.fits:   1%|          | 4.06k/559k [00:00<22:15, 415B/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_033600_TAI.Bt.fits:  21%|██▏       | 123k/573k [00:01<03:15, 2.31kB/s]
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.continuum.fits:  16%|█▌        | 50.9k/323k [00:00<05:25, 835B/s]
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bt.fits:   8%|▊         | 46.6k/573k [00:00<10:32, 833B/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bp.fits:   5%|▍         | 24.1k/510k [00:00<09:55, 816B/s]
#
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Br.fits:   2%|▏         | 12.6k/559k [00:00<15:23, 591B/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_033600_TAI.Bt.fits:  32%|███▏      | 183k/573k [00:01<01:58, 3.29kB/s]
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.continuum.fits:  26%|██▌       | 83.7k/323k [00:01<03:20, 1.19kB/s]
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bt.fits:  15%|█▍        | 83.7k/573k [00:01<06:52, 1.19kB/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bp.fits:   8%|▊         | 41.2k/510k [00:01<06:43, 1.16kB/s]
#
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Br.fits:   5%|▍         | 26.9k/559k [00:00<10:31, 842B/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_033600_TAI.Bt.fits:  45%|████▌     | 260k/573k [00:01<01:06, 4.68kB/s]
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.continuum.fits:  42%|████▏     | 135k/323k [00:01<01:50, 1.70kB/s]
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bt.fits:  23%|██▎       | 131k/573k [00:01<04:21, 1.69kB/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bp.fits:  13%|█▎        | 64.0k/510k [00:01<04:29, 1.65kB/s]
#
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Br.fits:   8%|▊         | 44.0k/559k [00:01<07:09, 1.20kB/s]
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.continuum.fits:  60%|█████▉    | 192k/323k [00:01<00:53, 2.42kB/s]
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bt.fits:  33%|███▎      | 187k/573k [00:01<02:40, 2.41kB/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bp.fits:  18%|█▊        | 94.0k/510k [00:01<02:56, 2.35kB/s]
#
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Br.fits:  13%|█▎        | 74.0k/559k [00:01<04:44, 1.71kB/s]
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.continuum.fits:  87%|████████▋ | 281k/323k [00:01<00:12, 3.45kB/s]
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bt.fits:  46%|████▌     | 264k/573k [00:01<01:30, 3.44kB/s]
# Files Downloaded:  19%|█▉        | 3/16 [00:03<00:19,  1.52s/file]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bp.fits:  25%|██▌       | 128k/510k [00:01<01:54, 3.34kB/s]
#
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Br.fits:  19%|█▊        | 104k/559k [00:01<03:07, 2.43kB/s]
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bt.fits:  60%|██████    | 346k/573k [00:01<00:46, 4.90kB/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bp.fits:  35%|███▍      | 178k/510k [00:01<01:09, 4.75kB/s]
#
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Br.fits:  27%|██▋       | 153k/559k [00:01<01:57, 3.45kB/s]
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bt.fits:  81%|████████  | 462k/573k [00:01<00:15, 6.97kB/s]
#
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Br.fits:  37%|███▋      | 204k/559k [00:01<01:12, 4.91kB/s]
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bt.fits:  89%|████████▉ | 509k/573k [00:02<00:06, 9.85kB/s]
#
# Files Downloaded:  25%|██▌       | 4/16 [00:04<00:13,  1.11s/file]
# We had some errors, here is log
# [error(filepath_partial=<function Downloader.enqueue_file.<locals>.filepath at 0x7f93ec72ee60>, url='http://jsoc.stanford.edu/SUM14/D1294198406/S00000/hmi.sharp_cea_720s.3604.20140108_032400_TAI.Bt.fits', exception=ClientConnectorError(ConnectionKey(host='jsoc.stanford.edu', port=80, is_ssl=False, ssl=None, proxy=None, proxy_auth=None, proxy_headers_hash=6904181561908916842), ConnectionRefusedError(111, "Connect call failed ('171.64.103.244', 80)"))), error(filepath_partial=<function Downloader.enqueue_file.<locals>.filepath at 0x7f93ec7030e0>, url='http://jsoc.stanford.edu/SUM14/D1294198406/S00000/hmi.sharp_cea_720s.3604.20140108_033600_TAI.Bp.fits', exception=ClientConnectorError(ConnectionKey(host='jsoc.stanford.edu', port=80, is_ssl=False, ssl=None, proxy=None, proxy_auth=None, proxy_headers_hash=6904181561908916842), ConnectionRefusedError(111, "Connect call failed ('171.64.103.244', 80)"))), error(filepath_partial=<function Downloader.enqueue_file.<locals>.filepath at 0x7f93ec72edd0>, url='http://jsoc.stanford.edu/SUM14/D1294198406/S00000/hmi.sharp_cea_720s.3604.20140108_032400_TAI.Bp.fits', exception=ClientConnectorError(ConnectionKey(host='jsoc.stanford.edu', port=80, is_ssl=False, ssl=None, proxy=None, proxy_auth=None, proxy_headers_hash=6904181561908916842), ConnectionRefusedError(111, "Connect call failed ('171.64.103.244', 80)"))), error(filepath_partial=<function Downloader.enqueue_file.<locals>.filepath at 0x7f93ec7033b0>, url='http://jsoc.stanford.edu/SUM14/D1294198406/S00000/hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bp.fits', exception=ClientConnectorError(ConnectionKey(host='jsoc.stanford.edu', port=80, is_ssl=False, ssl=None, proxy=None, proxy_auth=None, proxy_headers_hash=6904181561908916842), ConnectionRefusedError(111, "Connect call failed ('171.64.103.244', 80)"))), error(filepath_partial=<function Downloader.enqueue_file.<locals>.filepath at 0x7f93ec703200>, url='http://jsoc.stanford.edu/SUM14/D1294198406/S00000/hmi.sharp_cea_720s.3604.20140108_033600_TAI.Br.fits', exception=ClientConnectorError(ConnectionKey(host='jsoc.stanford.edu', port=80, is_ssl=False, ssl=None, proxy=None, proxy_auth=None, proxy_headers_hash=6904181561908916842), ConnectionRefusedError(111, "Connect call failed ('171.64.103.244', 80)"))), error(filepath_partial=<function Downloader.enqueue_file.<locals>.filepath at 0x7f93ec72e0e0>, url='http://jsoc.stanford.edu/SUM14/D1294198406/S00000/hmi.sharp_cea_720s.3604.20140108_031200_TAI.Br.fits', exception=ClientConnectorError(ConnectionKey(host='jsoc.stanford.edu', port=80, is_ssl=False, ssl=None, proxy=None, proxy_auth=None, proxy_headers_hash=6904181561908916842), ConnectionRefusedError(111, "Connect call failed ('171.64.103.244', 80)"))), error(filepath_partial=<function Downloader.enqueue_file.<locals>.filepath at 0x7f93ec72ef80>, url='http://jsoc.stanford.edu/SUM14/D1294198406/S00000/hmi.sharp_cea_720s.3604.20140108_033600_TAI.continuum.fits', exception=ClientConnectorError(ConnectionKey(host='jsoc.stanford.edu', port=80, is_ssl=False, ssl=None, proxy=None, proxy_auth=None, proxy_headers_hash=6904181561908916842), ConnectionRefusedError(111, "Connect call failed ('171.64.103.244', 80)"))), error(filepath_partial=<function Downloader.enqueue_file.<locals>.filepath at 0x7f93ec72eef0>, url='http://jsoc.stanford.edu/SUM14/D1294198406/S00000/hmi.sharp_cea_720s.3604.20140108_032400_TAI.Br.fits', exception=ClientConnectorError(ConnectionKey(host='jsoc.stanford.edu', port=80, is_ssl=False, ssl=None, proxy=None, proxy_auth=None, proxy_headers_hash=6904181561908916842), ConnectionRefusedError(111, "Connect call failed ('171.64.103.244', 80)"))), error(filepath_partial=<function Downloader.enqueue_file.<locals>.filepath at 0x7f93ec703170>, url='http://jsoc.stanford.edu/SUM14/D1294198406/S00000/hmi.sharp_cea_720s.3604.20140108_033600_TAI.Bt.fits', exception=ClientConnectorError(ConnectionKey(host='jsoc.stanford.edu', port=80, is_ssl=False, ssl=None, proxy=None, proxy_auth=None, proxy_headers_h ...
# Lets fetch them via requests library
# Content fetched, saving...
# File saved to ./data/3604/raw/hmi.sharp_cea_720s.3604.20140108_032400_TAI.Bt.fits
# Content fetched, saving...
# File saved to ./data/3604/raw/hmi.sharp_cea_720s.3604.20140108_033600_TAI.Bp.fits
# Content fetched, saving...
# File saved to ./data/3604/raw/hmi.sharp_cea_720s.3604.20140108_032400_TAI.Bp.fits
# Content fetched, saving...
# File saved to ./data/3604/raw/hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bp.fits
# Content fetched, saving...
# File saved to ./data/3604/raw/hmi.sharp_cea_720s.3604.20140108_033600_TAI.Br.fits
# Content fetched, saving...
# File saved to ./data/3604/raw/hmi.sharp_cea_720s.3604.20140108_031200_TAI.Br.fits
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Br.fits:  50%|█████     | 279k/559k [00:19<01:00, 4.62kB/s]
#
# hmi.sharp_cea_720s.3604.20140108_031200_TAI.Bp.fits:  50%|█████     | 255k/510k [00:19<01:19, 3.21kB/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_033600_TAI.Bt.fits:  50%|█████     | 287k/573k [00:18<01:01, 4.68kB/s]
#
#
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bp.fits:  50%|█████     | 255k/510k [00:17<00:53, 4.75kB/s]
#
#
# hmi.sharp_cea_720s.3604.20140108_034800_TAI.Br.fits:  50%|█████     | 279k/559k [00:17<00:56, 4.91kB/s]
# Content fetched, saving...
# File saved to ./data/3604/raw/hmi.sharp_cea_720s.3604.20140108_033600_TAI.continuum.fits
# Content fetched, saving...
# File saved to ./data/3604/raw/hmi.sharp_cea_720s.3604.20140108_032400_TAI.Br.fits
# Content fetched, saving...
# File saved to ./data/3604/raw/hmi.sharp_cea_720s.3604.20140108_033600_TAI.Bt.fits
# Content fetched, saving...
# File saved to ./data/3604/raw/hmi.sharp_cea_720s.3604.20140108_034800_TAI.Br.fits
# Content fetched, saving...
# File saved to ./data/3604/raw/hmi.sharp_cea_720s.3604.20140108_032400_TAI.continuum.fits
# Content fetched, saving...
# File saved to ./data/3604/raw/hmi.sharp_cea_720s.3604.20140108_031200_TAI.Bp.fits

# %%
print(result)
# Out:
# ['./data/3604/raw/hmi.sharp_cea_720s.3604.20140108_032400_TAI.continuum.fits', './data/3604/raw/hmi.sharp_cea_720s.3604.20140108_034800_TAI.Br.fits', './data/3604/raw/hmi.sharp_cea_720s.3604.20140108_033600_TAI.Bt.fits', './data/3604/raw/hmi.sharp_cea_720s.3604.20140108_033600_TAI.Bp.fits', './data/3604/raw/hmi.sharp_cea_720s.3604.20140108_031200_TAI.Br.fits', './data/3604/raw/hmi.sharp_cea_720s.3604.20140108_032400_TAI.Br.fits', './data/3604/raw/hmi.sharp_cea_720s.3604.20140108_034800_TAI.continuum.fits', './data/3604/raw/hmi.sharp_cea_720s.3604.20140108_031200_TAI.Bp.fits', './data/3604/raw/hmi.sharp_cea_720s.3604.20140108_031200_TAI.Bt.fits', './data/3604/raw/hmi.sharp_cea_720s.3604.20140108_032400_TAI.Bp.fits', './data/3604/raw/hmi.sharp_cea_720s.3604.20140108_032400_TAI.Bt.fits', './data/3604/raw/hmi.sharp_cea_720s.3604.20140108_033600_TAI.continuum.fits', './data/3604/raw/hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bp.fits', './data/3604/raw/hmi.sharp_cea_720s.3604.20140108_031200_TAI.continuum.fits', './data/3604/raw/hmi.sharp_cea_720s.3604.20140108_034800_TAI.Bt.fits', './data/3604/raw/hmi.sharp_cea_720s.3604.20140108_033600_TAI.Br.fits']

# %%
# Ok, lets process continuum images
cont = sorted([ res for res in result if 'continuum' in res])
print(cont)
# Out:
# ['./data/3604/raw/hmi.sharp_cea_720s.3604.20140108_031200_TAI.continuum.fits', './data/3604/raw/hmi.sharp_cea_720s.3604.20140108_032400_TAI.continuum.fits', './data/3604/raw/hmi.sharp_cea_720s.3604.20140108_033600_TAI.continuum.fits', './data/3604/raw/hmi.sharp_cea_720s.3604.20140108_034800_TAI.continuum.fits']

# %%
process_continuum(cont)
# Out:
# Dataset detected!
# Processing ...
# Setting up network...
# Loading weights...
# Predicting data...
# (1, 800, 1524, 1)
# Prediction took 3.6 seconds...
# Updating header ...
# Setting up network...
# Loading weights...
# Predicting data...
# (1, 800, 1524, 1)
# Prediction took 3.6 seconds...
# Updating header ...
# Setting up network...
# Loading weights...
# Predicting data...
# (1, 800, 1524, 1)
# Prediction took 3.6 seconds...
# Updating header ...
# Setting up network...
# Loading weights...
# Predicting data...
# (1, 800, 1524, 1)
# Prediction took 3.7 seconds...
# Updating header ...
# Processing done.
